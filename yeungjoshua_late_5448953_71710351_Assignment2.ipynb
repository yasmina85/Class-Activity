# %% [markdown]
# # Assignment 2: Getting data from Twitter API

# %% [markdown]
# For working on this assignment, the easiest way is to log into the [datahub.berkeley.edu](http://datahub.berkeley.edu). If you have a @berkeley.edu email address, you already have full access to the programming environment hosted on that site.

# %% [markdown]
# ## 1. Intro

# %% [markdown]
# Twitter collects a *lot* of data. Ranging from tweets themselves, to data about users, to data about likes and other interactions, Twitter basically records everything that happens on their website. Lucky for data scientists like ourselves, Twitter also shares that data with us! In this assignment, we're going to use Twitter's API to analyze retweet statistics, demographics, and some other data too!

# %% [markdown]
# ## 2. Importing Libraries

# %% [markdown]
# Other people are also interested in analyzing Twitter data, so there's been work done here already. That means other folks have developed useful collections of code — called libraries — which handle a lot of parsing and data management, so that we don't have to. Since these libraries are published online, we have access to all that hard work too! That means we can use code from those libraries to handle all the complicated Twitter models, so we only have to worry about the actual analysis (which is the fun part).

# %% [markdown]
# You don't need to worry too much about the code in the next cell. Its purpose is to install libraries that other people have written, so that we have access to them later on.

# %%
# !pip install tweepy    # This halps us access Twitter data.
# !pip install textblob  # This helps us parse text.
# !pip install plotly    # This makes it easy to plot graphs.
# !pip install nltk      # This is also to parse text.
# Out:
# Collecting tweepy
#   Using cached tweepy-3.5.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.7.3 in /srv/app/venv/lib/python3.6/site-packages (from tweepy)
# Collecting requests-oauthlib>=0.4.1 (from tweepy)
#   Using cached requests_oauthlib-0.8.0-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.4.3 in /srv/app/venv/lib/python3.6/site-packages (from tweepy)
# Collecting oauthlib>=0.6.2 (from requests-oauthlib>=0.4.1->tweepy)
#   Using cached oauthlib-2.0.4.tar.gz
# Building wheels for collected packages: oauthlib
#   Running setup.py bdist_wheel for oauthlib ... error
#   Complete output from command /srv/app/venv/bin/python3.6 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-jxhvf_5j/oauthlib/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/tmpsi27uyoupip-wheel- --python-tag cp36:
#   usage: -c [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: -c --help [cmd1 cmd2 ...]
#      or: -c --help-commands
#      or: -c cmd --help
#
#   error: invalid command 'bdist_wheel'
#
#   ----------------------------------------
#   Failed building wheel for oauthlib
#   Running setup.py clean for oauthlib
# Failed to build oauthlib
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
#   Running setup.py install for oauthlib ... done
# Successfully installed oauthlib-2.0.4 requests-oauthlib-0.8.0 tweepy-3.5.0
# Collecting textblob
#   Using cached textblob-0.13.0-py2.py3-none-any.whl
# Requirement already satisfied: nltk>=3.1 in /srv/app/venv/lib/python3.6/site-packages (from textblob)
# Requirement already satisfied: six in /srv/app/venv/lib/python3.6/site-packages (from nltk>=3.1->textblob)
# Installing collected packages: textblob
# Successfully installed textblob-0.13.0
# Collecting plotly
#   Using cached plotly-2.0.15.tar.gz
# Requirement already satisfied: decorator>=4.0.6 in /srv/app/venv/lib/python3.6/site-packages (from plotly)
# Requirement already satisfied: nbformat>=4.2 in /srv/app/venv/lib/python3.6/site-packages (from plotly)
# Requirement already satisfied: pytz in /srv/app/venv/lib/python3.6/site-packages (from plotly)
# Requirement already satisfied: requests in /srv/app/venv/lib/python3.6/site-packages (from plotly)
# Requirement already satisfied: six in /srv/app/venv/lib/python3.6/site-packages (from plotly)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /srv/app/venv/lib/python3.6/site-packages (from nbformat>=4.2->plotly)
# Requirement already satisfied: ipython-genutils in /srv/app/venv/lib/python3.6/site-packages (from nbformat>=4.2->plotly)
# Requirement already satisfied: traitlets>=4.1 in /srv/app/venv/lib/python3.6/site-packages (from nbformat>=4.2->plotly)
# Requirement already satisfied: jupyter-core in /srv/app/venv/lib/python3.6/site-packages (from nbformat>=4.2->plotly)
# Building wheels for collected packages: plotly
#   Running setup.py bdist_wheel for plotly ... error
#   Complete output from command /srv/app/venv/bin/python3.6 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-mxgiq8zm/plotly/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/tmp1l6xx6icpip-wheel- --python-tag cp36:
#   usage: -c [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: -c --help [cmd1 cmd2 ...]
#      or: -c --help-commands
#      or: -c cmd --help
#
#   error: invalid command 'bdist_wheel'
#
#   ----------------------------------------
#   Failed building wheel for plotly
#   Running setup.py clean for plotly
# Failed to build plotly
# Installing collected packages: plotly
#   Running setup.py install for plotly ... done
# Successfully installed plotly-2.0.15
# Requirement already satisfied: nltk in /srv/app/venv/lib/python3.6/site-packages
# Requirement already satisfied: six in /srv/app/venv/lib/python3.6/site-packages (from nltk)

# %% [markdown]
# ## 3. Accessing the Data

# %% [markdown]
# ### Question 1
# Follow these instructions to get your keys:
# To work on Twitter data, we'll first need two things: a Twitter account, and Twitter keys. Here are the steps to follow:
#
# 1. [Create a Twitter account](https://twitter.com).  You can use an existing account if you have one.
# 1. [Create a Twitter developer account](https://dev.twitter.com/resources/signup).  Attach it to your Twitter account.
# 1. Once you're logged into your developer account, [create an application for this assignment](https://apps.twitter.com/app/new).  You can call it whatever you want, and you can write any URL when it asks for a web site.
# 1. On the page for that application, find your Consumer Key and Consumer Secret. Don't lose these!
# 1. On the same page, create an Access Token. Record the resulting Access Token and Access Token Secret. Don't lose these either!
#
# **Security concern:** DO NOT share your access keys with anyone. They can be used to manage your Twitter account without your permission.

# %% [markdown]
# Add your credentials in the cell below. Your program will use them to access Twitter data.

# %%
consumer_key = ""
consumer_secret = ""
access_key = ""
access_secret = ""

# %% [markdown]
# The next cell will authorize your program to request Twitter data, through the developer account you just set up.

# %%
import tweepy
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %% [markdown]
# **Note**: A lot of data scientists like Twitter data. As a result, you can only request data approximately once every 15 minutes to keep Twitter's servers from crashing due to too much activity. Use your requests wisely to avoid unnecessary waiting time.

# %% [markdown]
# ### Question 2:
# [Twitter API](https://dev.twitter.com/overview/api) can be used for retrieving different objects (e.g., tweets). List the other possible objects that can be retrieved by Twitter API.

# %% [markdown]
# **Answer:**
# 1. User
# 2. Entity
# 3. Place

# %% [markdown]
# Now that everything is set up, we can use [Twitter's search API](https://dev.twitter.com/rest/reference/get/search/tweets) to find the word "Berkeley". This will give us the same results as using [Twitter's online "search" page](https://twitter.com/search?q=berkeley).

# %%
results = tweepy.Cursor(api.search,   # `api.search` specifies we want to perform a search.
                        q='Berkeley', # `q` is the query, or the words we're searching for.
                        result_type='popular') # We'll prioritize more popular results first.

# %% [markdown]
# Now `results` is a long list of search results. Since it is actually pretty extensive, let's just take the first ten results. In the next cell we build up a list called `first_ten`, which contains just the first ten tweets we found in `results`.

# %%
first_ten = []                  # We start out with an empty list called `first_ten`.
for tweet in results.items(100): # Then, we'll iterate over the first 10 tweets in `results`...
    first_ten.append(tweet)     # And we'll add each of those tweets to `first_ten`.

# %% [markdown]
# Now lets have a peek at what the data looks like.

# %%
print(first_ten)
# Out:
# [Status(_api=<tweepy.api.API object at 0x7ff48442a0f0>, _json={'created_at': 'Wed Sep 13 00:20:31 +0000 2017', 'id': 907760870071074818, 'id_str': '907760870071074818', 'text': 'More than $60K has been raised for a hot dog vendor after video of UC Berkeley cops seizing his money went viral:… https://t.co/qjJ3m8DoCJ', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/qjJ3m8DoCJ', 'expanded_url': 'https://twitter.com/i/web/status/907760870071074818', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [115, 138]}]}, 'metadata': {'result_type': 'popular', 'iso_language_code': 'en'}, 'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 20097362, 'id_str': '20097362', 'name': 'NBC Bay Area', 'screen_name': 'nbcbayarea', 'location': 'San Francisco Bay Area', 'description': 'Thank you for stopping by @NBCBayArea - the place to go for exclusive local stories, breaking news, weather and sports. Facebook: https://t.co/1wlYqKBZsQ', 'url': 'https://t.co/GItaIcePJK', 'entities': {'url': {'urls': [{'url': 'https://t.co/GItaIcePJK', 'expanded_url': 'http://nbcbayarea.com', 'display_url': 'nbcbayarea.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/1wlYqKBZsQ', 'expanded_url': 'http://facebook.com/NBCBayArea', 'display_url': 'facebook.com/NBCBayArea', 'indices': [130, 153]}]}}, 'protected': False, 'followers_count': 276089, 'friends_count': 2548, 'listed_count': 3097, 'created_at': 'Wed Feb 04 21:41:26 +0000 2009', 'favourites_count': 4337, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': True, 'verified': True, 'statuses_count': 225761, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '0082C8', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/723861891/b314019172979d99ed50f5d45be491b5.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/723861891/b314019172979d99ed50f5d45be491b5.jpeg', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/897669677123485697/hPohfgNt_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/897669677123485697/hPohfgNt_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/20097362/1483399801', 'profile_link_color': '0099B9', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '95E8EC', 'profile_text_color': '3C3940', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 18998, 'favorite_count': 41920, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2017, 9, 13, 0, 20, 31), id=907760870071074818, id_str='907760870071074818', text='More than $60K has been raised for a hot dog vendor after video of UC Berkeley cops seizing his money went viral:… https://t.co/qjJ3m8DoCJ', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/qjJ3m8DoCJ', 'expanded_url': 'https://twitter.com/i/web/status/907760870071074818', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [115, 138]}]}, metadata={'result_type': 'popular', 'iso_language_code': 'en'}, source='SocialFlow', source_url='http://www.socialflow.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, ...

# %% [markdown]
# ## 4. Exploring the Dataset

# %% [markdown]
# Twitter gives us a lot of information about each tweet, not just its text. You can read about all the details [here](https://dev.twitter.com/overview/api/tweets). Let's look at one tweet to get a sense of the information we have available. We can access just the first tweet in our list by indexing into it. Note, the first index in the list is actually 0, not 1, so we will actually say `first_ten[0]` to see the first tweet in our list of ten tweets.

# %%
print(first_ten[0]) # Try changing this to any number 0-9, to see other tweets in the list.
# Out:
# Status(_api=<tweepy.api.API object at 0x7ff48442a0f0>, _json={'created_at': 'Wed Sep 13 00:20:31 +0000 2017', 'id': 907760870071074818, 'id_str': '907760870071074818', 'text': 'More than $60K has been raised for a hot dog vendor after video of UC Berkeley cops seizing his money went viral:… https://t.co/qjJ3m8DoCJ', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/qjJ3m8DoCJ', 'expanded_url': 'https://twitter.com/i/web/status/907760870071074818', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [115, 138]}]}, 'metadata': {'result_type': 'popular', 'iso_language_code': 'en'}, 'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 20097362, 'id_str': '20097362', 'name': 'NBC Bay Area', 'screen_name': 'nbcbayarea', 'location': 'San Francisco Bay Area', 'description': 'Thank you for stopping by @NBCBayArea - the place to go for exclusive local stories, breaking news, weather and sports. Facebook: https://t.co/1wlYqKBZsQ', 'url': 'https://t.co/GItaIcePJK', 'entities': {'url': {'urls': [{'url': 'https://t.co/GItaIcePJK', 'expanded_url': 'http://nbcbayarea.com', 'display_url': 'nbcbayarea.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/1wlYqKBZsQ', 'expanded_url': 'http://facebook.com/NBCBayArea', 'display_url': 'facebook.com/NBCBayArea', 'indices': [130, 153]}]}}, 'protected': False, 'followers_count': 276089, 'friends_count': 2548, 'listed_count': 3097, 'created_at': 'Wed Feb 04 21:41:26 +0000 2009', 'favourites_count': 4337, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': True, 'verified': True, 'statuses_count': 225761, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '0082C8', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/723861891/b314019172979d99ed50f5d45be491b5.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/723861891/b314019172979d99ed50f5d45be491b5.jpeg', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/897669677123485697/hPohfgNt_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/897669677123485697/hPohfgNt_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/20097362/1483399801', 'profile_link_color': '0099B9', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '95E8EC', 'profile_text_color': '3C3940', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 18998, 'favorite_count': 41920, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2017, 9, 13, 0, 20, 31), id=907760870071074818, id_str='907760870071074818', text='More than $60K has been raised for a hot dog vendor after video of UC Berkeley cops seizing his money went viral:… https://t.co/qjJ3m8DoCJ', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/qjJ3m8DoCJ', 'expanded_url': 'https://twitter.com/i/web/status/907760870071074818', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [115, 138]}]}, metadata={'result_type': 'popular', 'iso_language_code': 'en'}, source='SocialFlow', source_url='http://www.socialflow.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None,  ...

# %%
print(first_ten[0].text) # Try this and inspect what it does
# Out:
# More than $60K has been raised for a hot dog vendor after video of UC Berkeley cops seizing his money went viral:… https://t.co/qjJ3m8DoCJ

# %%
print(first_ten[0].created_at) # Try this and inspect what it does
# Out:
# 2017-09-13 00:20:31

# %% [markdown]
# ### Question 3:
# Which field contains each of the following attributes:
# 1. The tweet's text?
# 1. The time when the tweet was posted?
# 1. The geographic location of the tweet?
# 1. The source (device and app) where the tweet was written?

# %% [markdown]
# 1. text
# 2. created_at
# 3. coordinates
# 4. source

# %% [markdown]
# ## 5. Analyzing the Dataset

# %% [markdown]
# It's time to do analysis! Let's start out by getting a list, where each entry corresponds to how many retweets we got in the first

# %%
retweet_counts = []                      # We start with an empty list called `retweet_counts`.
for tweet in first_ten:                  # Then, we iterate over the tweets in `first_ten`...
    retweet_count = tweet.retweet_count  # And, for each tweet, get the number of retweets...
    retweet_counts.append(retweet_count) # And append that number to our list `retweet_counts`.


print(retweet_counts)
# Out:
# [18998, 4871, 6497, 8767, 69, 1943, 5172, 43, 44, 1664, 3458, 2651, 2235, 4057, 4336]

# %% [markdown]
# Let's try and draw it:

# %%
import matplotlib.pyplot as plt
plt.hist(retweet_counts)
plt.xlabel("Retweet counts")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Question 4
# Twitter search api provides three modes (check out this [guide](https://dev.twitter.com/rest/reference/get/search/tweets)) for the result_type: mix, recent, and popular. In the previous code, we retrieved the popular tweets.
# Now it is your turn to retrieve recent 100 tweets and assign them to a new variable (e.g., results_recent100), then plot a histogram for the retweet count of the recent 100 tweets. You can follow our example code if you wish.

# %% [markdown]
# **Answer**

# %%
import matplotlib.pyplot as plt
recents = tweepy.Cursor(api.search,   # `api.search` specifies we want to perform a search.
                        q='Berkeley', # `q` is the query, or the words we're searching for.
                        result_type='recent')

results_recent100 = []                  # We start out with an empty list called `first_ten`.
for tweet in recents.items(100): # Then, we'll iterate over the first 10 tweets in `results`...
    results_recent100.append(tweet) 
    
retweet_countz = []                      # We start with an empty list called `retweet_counts`.
for tweet in results_recent100:                  # Then, we iterate over the tweets in `first_ten`...
    retweet_count = tweet.retweet_count  # And, for each tweet, get the number of retweets...
    retweet_countz.append(retweet_count) # And append that number to our list `retweet_counts`.

print(retweet_countz)
plt.hist(retweet_countz)
plt.xlabel("Retweet counts")
plt.ylabel("Frequency")
plt.show()
# Out:
# [5, 0, 0, 0, 0, 64, 1, 0, 4, 223, 0, 2, 0, 0, 2, 0, 0, 40, 0, 77, 502, 1, 38, 5, 2, 502, 502, 0, 17, 0, 1, 64, 0, 2, 0, 38, 502, 0, 0, 0, 1, 0, 0, 38, 64, 0, 0, 1281, 64, 2, 4, 223, 2185, 0, 47, 0, 4057, 0, 0, 64, 9, 38, 2, 1, 502, 223, 0, 502, 265, 3, 4, 1, 3, 326, 0, 502, 64, 5, 326, 73, 0, 1, 4057, 502, 502, 0, 0, 1, 4, 502, 1, 38, 0, 474, 502, 20, 2, 38, 20, 1030]

# %% [markdown]
# ### Question 5
# Compare and contrast between the two histograms for retweet counts of recent and popular 100 tweets that returns from searching the word Berkeley.

# %% [markdown]
# **Answer**:

# %%
#The density of the popular 100 tweet histogram is more spread out over 9000 retweet count units, while for recent 100, we see over 80% of the retweet counts between 0 and 500 retweet counts, so the histogram is higher and skewed right.

# %% [markdown]
# ## Users
# Instead of searching for tweets, you can use Twitter APIs to get details about specific user account. It includes user’s timeline, followers, etc.
#
# Get the latest 10 tweets from an account that interests you (e.g.,  UCBerkeley) twitter account using the following code.

# %%
user_results = api.user_timeline(screen_name='UCBerkeley', count=10)

user_results_tweets = []           # We start with an empty list called user_results_tweets

for t in user_results:             #Then, we iterate over the tweets in user_results
    user_results_tweets.append(t)  #And we'll add each of those tweets to user_results_tweets

# %%
#Let's look at one tweet
print(user_results_tweets[0])
# Out:
# Status(_api=<tweepy.api.API object at 0x7ff48442a0f0>, _json={'created_at': 'Tue Sep 19 02:09:13 +0000 2017', 'id': 909962554340003841, 'id_str': '909962554340003841', 'text': 'RT @UCBerkeleyNews: Mary-Claire King was a @UCBerkeley prof when her husband left her &amp; burglars tore apart her home; read her story https:…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'UCBerkeleyNews', 'name': 'UC Berkeley News', 'id': 30275911, 'id_str': '30275911', 'indices': [3, 18]}, {'screen_name': 'UCBerkeley', 'name': 'UC Berkeley', 'id': 176932593, 'id_str': '176932593', 'indices': [43, 54]}], 'urls': []}, 'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 176932593, 'id_str': '176932593', 'name': 'UC Berkeley', 'screen_name': 'UCBerkeley', 'location': 'Berkeley, California', 'description': 'University of California, Berkeley, the premier public institution of higher education', 'url': 'http://t.co/5AQcLU8aoE', 'entities': {'url': {'urls': [{'url': 'http://t.co/5AQcLU8aoE', 'expanded_url': 'http://berkeley.edu', 'display_url': 'berkeley.edu', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 127472, 'friends_count': 1167, 'listed_count': 1614, 'created_at': 'Tue Aug 10 20:40:13 +0000 2010', 'favourites_count': 6378, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'verified': True, 'statuses_count': 13290, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FCFCFC', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/176932593/1398457126', 'profile_link_color': '9D7D0A', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F9EFC8', 'profile_text_color': '152C9D', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Sep 18 22:08:08 +0000 2017', 'id': 909901881203453952, 'id_str': '909901881203453952', 'text': 'Mary-Claire King was a @UCBerkeley prof when her husband left her &amp; burglars tore apart her home; read her story… https://t.co/w41WH2gACA', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'UCBerkeley', 'name': 'UC Berkeley', 'id': 176932593, 'id_str': '176932593', 'indices': [23, 34]}], 'urls': [{'url': 'https://t.co/w41WH2gACA', 'expanded_url': 'https://twitter.com/i/web/status/909901881203453952', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [118, 141]}]}, 'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 30275911, 'id_str': '30275911', 'name': 'UC Berkeley News', 'screen_name': 'UCBerkeleyNews', 'location': 'Berkeley, California', 'description': 'News from, for and about UC Berkeley', 'url': 'http://t.co/X8Br8uv6YP', 'entities': {'url': {'urls': [{'url': 'http://t.c ...

# %%
#print the text of the first 10 tweets
for tweet in user_results_tweets:
    print(tweet.created_at.strftime("%Y-%b-%d %H:%M"))
    print(tweet.text)
    print()
# Out:
# 2017-Sep-19 02:09
# RT @UCBerkeleyNews: Mary-Claire King was a @UCBerkeley prof when her husband left her &amp; burglars tore apart her home; read her story https:…
#
# 2017-Sep-19 01:42
# RT @brklyartsdesign: Tonight Arlie Hochschild discusses her book 'Strangers in their own land' with performances  by @UCBerkeley students #…
#
# 2017-Sep-19 01:03
# RT @BerkeleyLawNews: Dean Chemerinsky &amp; @Harvard_Law Lawrence Tribe @tribelaw join suit vs Trump on behalf of #DACA recipients https://t.co…
#
# 2017-Sep-19 00:04
# RT @GreaterGoodSC: Find your unique road to happiness with The Science of Happiness--a free course from UC Berkeley https://t.co/Kb2WfRLkQu
#
# 2017-Sep-18 22:15
# BLOG by @profjohnapowell https://t.co/9LeHPyMIMk #freespeech
#
# 2017-Sep-18 22:04
# RT @CalFootball: Congrats @aaronrodgers12 #ProBears https://t.co/S7WEm6I1LR
#
# 2017-Sep-18 19:02
# RT @UCBerkeley: Join the #freespeech conversation! https://t.co/CyqQPk1uNy
#
# 2017-Sep-18 18:24
# Join the #freespeech conversation! https://t.co/CyqQPk1uNy
#
# 2017-Sep-18 17:03
# Scientists pinpoint 27 states of emotion https://t.co/za1n2vdvgX https://t.co/42ru10sxPB
#
# 2017-Sep-18 07:30
# Distant galaxy sends out 15 high-energy radio bursts https://t.co/WVuMlJjOyB https://t.co/AmIWgBfmt6

# %% [markdown]
# ### Question 6
#
# Look at the text of retrieved tweets and compare them to the latest 10 tweets of the [web interface](https://twitter.com/UCBerkeley) for the same user. Do you see any difference?

# %% [markdown]
# Twitter has a "pinned tweet" that doesn't appear on our list of retrieved tweets, for the rest of the tweets are the same as the ones on Twitter right now, in the same order.

# %% [markdown]
# Get a list of a followers for UCBerkeley.

# %%
followers_list = []

followers_results = api.followers(screen_name='UCBerkeley', count=200, page=1)
for f in followers_results:
      followers_list.append(f)

for f in followers_list:
    print(f.name)
# Out:
# MD
# Felipe Abreo
# Checho Waldo
# Scott Hyman
# Corpus VEC Fellow
# 4r4d
# Danielson
# Nicole Hashemi
# Nikolai Kirienko
# Karime Sánchez G
# Michelle Chang
# Lisa Cremer
# driss naciri
# WET_edugames
# Anne Megaro
# Barbora Sedova
# JustinBathory
# UN Human Rights
# Tina Noordeh
# ryan underwood
# Jimmy Song
# Zach Kemp
# Kazuki (コジコジ)
# College Town Baby
# Alix
# Mete
# Aastik SajanRambooti
# Feuilliton
# Roz Plater
# Nils
# d
# Fishers
# Lucy in the sky
# Anna Carolyan
# Gerlen Anderson
# Usha
# İsmailİsmailovOzturk
# Daniel Lacalle
# NIOSHbreathe
# Marta C. Gonzalez
# DASCS3
# William Blacoe
# Susanne Milde
# • » ιѕнαη gσєℓ « •
# M. Ferhat Aktaş
# K
# sydney
# Kooz
# Subhash Thapa
# Clayton Wyrick
# qixiong
# Andy Iyengar
# Abhilash Kumar
# furkan#inc
# Wil Tang
# Jhoya
# Gabriel Rocha
# melissa monroy
# HairuAn
# Higvhh
# vizzz
# Mohammed Shuaib
# Wen-Jia Wu
# Suhail Kandak
# Dreammaker
# Nick Aparicio
# autumn ((:
# Farah
# Nicolás Quiñones
# dani.🌹
# gráinne b
# abraham velasquez
# ems
# Jsnsndndnnnf
# SpaceDreams_1
# Victor
# holly
# Joanne Shin
# Michael Paque
# H. Castle
# Daniel RF
# Doc
# Jessica Chen
# GE Ausbon
# 신미진
# Andres Tassara
# Vernon
# Rajesh kumar
# Hrag Barsoumian
# Water Boy.
# Peter Berzins
# Lewis G.
# Youmna Rabie
# Wendy perez
# Marisel Della Togna
# Kevin Bo
# Roberto Molina Q.
# olivia
# Chan pol
# Parshva Mody
# Uyen P
# andy chen
# T H M P S N
# Max Buydakov
# Nannette thompson
# Dylan Beal
# Petya Tsekova
# 💀
# Louis Theroux
# Rafael Ortiz, PhD
# carlos francavilla
# Dana
# GMS College Club
# Make up Your Mind
# Anonym Tipster
# Meghan Barnes
# Juan Carlos Lemus
# Shahzaib
# Junaid Ahmad
# ⚠Jeffrey Horrocks⚠
# Dan phillips
# La Rossa
# Tradlyf 💀🐶🌹
# Foudil Feddal
# Yiyang Li
# mitch
# Mary Jane
# M Abdullah Canbaz
# Emin Aliyev
# Carlos Cota Estévez
# Michael Monaghan
# Pete Coupland
# AnnA
# Simon Neby
# Dave
# Joe Owens
# Rebecca Burns
# KR Beringer
# MooseMan🐸🌺🇨🇦👌
# Sally Anne Taylor
# Blue Streak Science
# J Bloch
# Edgar Cordero
# Nsuhoridem Jackson
# pandapop1776
# David Bradford
# Mari Andersen
# Samuel Lukudu
# UBIT Wien
# Carlos Magalhães
# ArtJobsInHighEd
# Anne Evered
# Krupesh Laiya
# yunfan
# JAK
# Vinod Ganesan
# CBircan_
# Kiky S. Janis
# Utama Amara
# Juan
# Alberto Antoran
# fats
# ※※※
# burcu g.s.
# Omprakash Jailia
# Garam Choi
# Carmen Boniferro
# Mohammed Tafazzul
# HelpMeLearnThis
# name cannot be blank
# 王萍
# JOSE LUIS DE ARAUJO
# Alexia_9500
# thigh/akaDesireD.
# hollybelle
# gypsydanny415
# vrushali
# DavidSBoulanger
# L. Zuccaro Marchi
# 凌晨
# chiru swarna
# Maureen Aquino
# stephan
# Kayla
# Daphney not Daphne
# greenbiketours
# nalin walpola
# Henry Morales
# Vikas Wadhwa
# Nicholas Hirsch
# K
# Conquista Del Pan
# Huaixin Wang
# MsAdams
# Luke Blackett
# DesignWomenSF
# Christopher Finnie
# nat
# Deb Sue
# Paramvir Singh

# %% [markdown]
# There’s a limit on how many users can be returned by one request. If you need more, please read [using cursors to navigate collections](https://dev.twitter.com/overview/api/cursoring).

# %% [markdown]
# ### Extra Credit Question
# We saw how to use Twitter API to search for tweets. The [Search API](https://dev.twitter.com/rest/public/search) has an option to filter the query results by geo location. The parameter value is specified by ”latitude,longitude,radius” (check out the documentation of API  for more information). Compare the top 10 popular tweets text that contain the word 'berkeley' from four geo locations: Berkeley, Kansas City, New York, and Barcelona Spain.

# %% [markdown]
# **Answer:**

# %%
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /srv/app/venv/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     390                     # otherwise it looks like a programming error was the cause.
# --> 391                     six.raise_from(e, None)
#     392         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /srv/app/venv/lib/python3.6/site-packages/requests/packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /srv/app/venv/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                 try:
# --> 387                     httplib_response = conn.getresponse()
#     388                 except Exception as e:
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1001                   self.__class__)
# -> 1002             return self.read(nbytes, buffer)
#    1003         else:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     864         try:
# --> 865             return self._sslobj.read(len, buffer)
#     866         except SSLError as x:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     624         if buffer is not None:
# --> 625             v = self._sslobj.read(len, buffer)
#     626         else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# /srv/app/venv/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# /srv/app/venv/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     642             retries = retries.increment(method, url, error=e, _pool=self,
# --> 643                                         _stacktrace=sys.exc_info()[2])
#     644             retries.sleep()
#
# /srv/app/venv/lib/python3.6/site-packages/requests/packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     333             if read is False:
# --> 334                 raise six.reraise(type(error), error, _stacktrace)
#     335             elif read is not None:
#
# /srv/app/venv/lib/python3.6/site-packages/requests/packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     685             raise value.with_traceback(tb)
# --> 686         raise value
#     687
#
# /srv/app/venv/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#
# /srv/app/venv/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     392         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 393             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     394             raise
#
# /srv/app/venv/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     312         if isinstance(err, SocketTimeout):
# --> 313             raise ReadTimeoutError(self, url, "Read timed out. (read timeout=%s)" % timeout_value)
#     314
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out. (read timeout=60)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# /srv/app/venv/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     186                                                 auth=auth,
# --> 187                                                 proxies=self.api.proxy)
#     188                 except Exception as e:
#
# /srv/app/venv/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#
# /srv/app/venv/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#
# /srv/app/venv/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     498             elif isinstance(e, ReadTimeoutError):
# --> 499                 raise ReadTimeout(e, request=request)
#     500             else:
#
# ReadTimeout: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out. (read timeout=60)
#
# During handling of the above exception, another exception occurred:
#
# TweepError                                Traceback (most recent call last)
# <ipython-input-65-c680f269951e> in <module>()
#       4
#       5 first_ten = [] # We start out with an empty list called `first_ten`.
# ----> 6 for tweet in results.items(10): # Then, we'll iterate over the first 10 tweets in `results`...
#       7     first_ten.append(tweet)
#
# /srv/app/venv/lib/python3.6/site-packages/tweepy/cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# /srv/app/venv/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# /srv/app/venv/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     106
#     107         if self.index >= len(self.results) - 1:
# --> 108             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     109
#     110             if hasattr(self.method, '__self__'):
#
# /srv/app/venv/lib/python3.6/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     243             return method
#     244         else:
# --> 245             return method.execute()
#     246
#     247     # Set pagination mode
#
# /srv/app/venv/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     187                                                 proxies=self.api.proxy)
#     188                 except Exception as e:
# --> 189                     raise TweepError('Failed to send request: %s' % e)
#     190                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#     191                 if rem_calls is not None:
#
# TweepError: Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out. (read timeout=60)

# %% [markdown]
# ### Extra Credit Question
# Based on profile_location in the follower data, Compare between the followers of Donald Trump and Hillary Clinton in terms of their locations. Draw a map for both followers lists.

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Submitting the assignment
#
# - Delete your Twitter API credentials, ie. re-assign `consumer_key`, `consumer_secret`, `access_key`, and `access_secret` to empty strings so that we won't see your credentials when you save and sumbit it.
# - Save this jupyter notebook as a pdf. Click File, Download as, PDF via LaTex (.pdf).
# - Upload the pdf file into bcourses under Assignment 2.

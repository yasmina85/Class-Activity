# %% [markdown]
# # Assignment 2: Getting data from Twitter API

# %% [markdown]
# For working on this assignment, the easiest way is to log into the [datahub.berkeley.edu](http://datahub.berkeley.edu). If you have a @berkeley.edu email address, you already have full access to the programming environment hosted on that site.

# %% [markdown]
# ## 1. Intro

# %% [markdown]
# Twitter collects a *lot* of data. Ranging from tweets themselves, to data about users, to data about likes and other interactions, Twitter basically records everything that happens on their website. Lucky for data scientists like ourselves, Twitter also shares that data with us! In this assignment, we're going to use Twitter's API to analyze retweet statistics, demographics, and some other data too!

# %% [markdown]
# ## 2. Importing Libraries

# %% [markdown]
# Other people are also interested in analyzing Twitter data, so there's been work done here already. That means other folks have developed useful collections of code — called libraries — which handle a lot of parsing and data management, so that we don't have to. Since these libraries are published online, we have access to all that hard work too! That means we can use code from those libraries to handle all the complicated Twitter models, so we only have to worry about the actual analysis (which is the fun part).

# %% [markdown]
# You don't need to worry too much about the code in the next cell. Its purpose is to install libraries that other people have written, so that we have access to them later on.

# %%
# !pip install tweepy    # This halps us access Twitter data.
# !pip install textblob  # This helps us parse text.
# !pip install plotly    # This makes it easy to plot graphs.
# !pip install nltk      # This is also to parse text.
# Out:
# Requirement already satisfied: tweepy in /srv/app/venv/lib/python3.6/site-packages
# Requirement already satisfied: requests>=2.4.3 in /srv/app/venv/lib/python3.6/site-packages (from tweepy)
# Requirement already satisfied: six>=1.7.3 in /srv/app/venv/lib/python3.6/site-packages (from tweepy)
# Requirement already satisfied: requests-oauthlib>=0.4.1 in /srv/app/venv/lib/python3.6/site-packages (from tweepy)
# Requirement already satisfied: oauthlib>=0.6.2 in /srv/app/venv/lib/python3.6/site-packages (from requests-oauthlib>=0.4.1->tweepy)
# Requirement already satisfied: textblob in /srv/app/venv/lib/python3.6/site-packages
# Requirement already satisfied: nltk>=3.1 in /srv/app/venv/lib/python3.6/site-packages (from textblob)
# Requirement already satisfied: six in /srv/app/venv/lib/python3.6/site-packages (from nltk>=3.1->textblob)
# Requirement already satisfied: plotly in /srv/app/venv/lib/python3.6/site-packages
# Requirement already satisfied: decorator>=4.0.6 in /srv/app/venv/lib/python3.6/site-packages (from plotly)
# Requirement already satisfied: nbformat>=4.2 in /srv/app/venv/lib/python3.6/site-packages (from plotly)
# Requirement already satisfied: pytz in /srv/app/venv/lib/python3.6/site-packages (from plotly)
# Requirement already satisfied: requests in /srv/app/venv/lib/python3.6/site-packages (from plotly)
# Requirement already satisfied: six in /srv/app/venv/lib/python3.6/site-packages (from plotly)
# Requirement already satisfied: ipython-genutils in /srv/app/venv/lib/python3.6/site-packages (from nbformat>=4.2->plotly)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /srv/app/venv/lib/python3.6/site-packages (from nbformat>=4.2->plotly)
# Requirement already satisfied: traitlets>=4.1 in /srv/app/venv/lib/python3.6/site-packages (from nbformat>=4.2->plotly)
# Requirement already satisfied: jupyter-core in /srv/app/venv/lib/python3.6/site-packages (from nbformat>=4.2->plotly)
# Requirement already satisfied: nltk in /srv/app/venv/lib/python3.6/site-packages
# Requirement already satisfied: six in /srv/app/venv/lib/python3.6/site-packages (from nltk)

# %% [markdown]
# ## 3. Accessing the Data

# %% [markdown]
# ### Question 1
# Follow these instructions to get your keys:
# To work on Twitter data, we'll first need two things: a Twitter account, and Twitter keys. Here are the steps to follow:
#
# 1. [Create a Twitter account](https://twitter.com).  You can use an existing account if you have one.
# 1. [Create a Twitter developer account](https://dev.twitter.com/resources/signup).  Attach it to your Twitter account.
# 1. Once you're logged into your developer account, [create an application for this assignment](https://apps.twitter.com/app/new).  You can call it whatever you want, and you can write any URL when it asks for a web site.
# 1. On the page for that application, find your Consumer Key and Consumer Secret. Don't lose these!
# 1. On the same page, create an Access Token. Record the resulting Access Token and Access Token Secret. Don't lose these either!
#
# **Security concern:** DO NOT share your access keys with anyone. They can be used to manage your Twitter account without your permission.

# %% [markdown]
# Add your credentials in the cell below. Your program will use them to access Twitter data.

# %%
consumer_key = "cuh0rJTiHrh124QZDKpOeDKoz"
consumer_secret = "plwlMe8ZrFNfuDsKj5qkYpyx9VrPlifsr7E5KdwE0Vtc1vINpO"
access_key = "919709372636323840-vw8dxA2KYAkIF9Mbcd9bX1bZ7Bzo9I9"
access_secret = "7UsoejW3ww4z5adqftnLd9NTmXt8bHg5Yf7JmYhE2IVKL"

# %% [markdown]
# The next cell will authorize your program to request Twitter data, through the developer account you just set up.

# %%
import tweepy
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %% [markdown]
# **Note**: A lot of data scientists like Twitter data. As a result, you can only request data approximately once every 15 minutes to keep Twitter's servers from crashing due to too much activity. Use your requests wisely to avoid unnecessary waiting time.

# %% [markdown]
# ### Question 2:
# [Twitter API](https://dev.twitter.com/overview/api) can be used for retrieving different objects (e.g., tweets). List the other possible objects that can be retrieved by Twitter API.

# %% [markdown]
# **Answer:**
# 1. Users
# 1. Entities
# 1. Places

# %% [markdown]
# Now that everything is set up, we can use [Twitter's search API](https://dev.twitter.com/rest/reference/get/search/tweets) to find the word "Berkeley". This will give us the same results as using [Twitter's online "search" page](https://twitter.com/search?q=berkeley).

# %%
results = tweepy.Cursor(api.search,   # `api.search` specifies we want to perform a search.
                        q='Berkeley', # `q` is the query, or the words we're searching for.
                        result_type='popular') # We'll prioritize more popular results first.

# %% [markdown]
# Now `results` is a long list of search results. Since it is actually pretty extensive, let's just take the first ten results. In the next cell we build up a list called `first_ten`, which contains just the first ten tweets we found in `results`.

# %%
first_ten = []                  # We start out with an empty list called `first_ten`.
for tweet in results.items(10): # Then, we'll iterate over the first 10 tweets in `results`...
    first_ten.append(tweet)     # And we'll add each of those tweets to `first_ten`.

# %% [markdown]
# Now lets have a peek at what the data looks like.

# %%
print(first_ten)
# Out:
# [Status(_api=<tweepy.api.API object at 0x7fbd07feac50>, _json={'created_at': 'Sun Oct 15 01:55:00 +0000 2017', 'id': 919381060928004096, 'id_str': '919381060928004096', 'text': 'JW revealed Berkeley mayor assured Mexican govt his #SanctuaryCity will still provide safe space for illegal aliens.\nhttps://t.co/shsqbzDxzG', 'truncated': False, 'entities': {'hashtags': [{'text': 'SanctuaryCity', 'indices': [52, 66]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/shsqbzDxzG', 'expanded_url': 'http://jwatch.us/U9iTP8', 'display_url': 'jwatch.us/U9iTP8', 'indices': [117, 140]}]}, 'metadata': {'result_type': 'popular', 'iso_language_code': 'en'}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 18247062, 'id_str': '18247062', 'name': 'Judicial Watch 🔎', 'screen_name': 'JudicialWatch', 'location': 'Washington, DC', 'description': 'A conservative non-partisan educational foundation promoting transparency, accountability, & integrity in government. Follow us on Instagram: judicialwatch', 'url': 'https://t.co/JPjqvKy5es', 'entities': {'url': {'urls': [{'url': 'https://t.co/JPjqvKy5es', 'expanded_url': 'http://www.judicialwatch.org', 'display_url': 'judicialwatch.org', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 547185, 'friends_count': 1991, 'listed_count': 3919, 'created_at': 'Fri Dec 19 18:04:57 +0000 2008', 'favourites_count': 1184, 'utc_offset': -14400, 'time_zone': 'Eastern Time (US & Canada)', 'geo_enabled': True, 'verified': True, 'statuses_count': 19720, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'ABB8C2', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000013831580/0608d68919323081fdb3ca5c24a9db1a.gif', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000013831580/0608d68919323081fdb3ca5c24a9db1a.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/794591644007993344/pvlIf0w6_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/794591644007993344/pvlIf0w6_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18247062/1492114697', 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'EEEEEE', 'profile_text_color': '30353B', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 454, 'favorite_count': 402, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2017, 10, 15, 1, 55), id=919381060928004096, id_str='919381060928004096', text='JW revealed Berkeley mayor assured Mexican govt his #SanctuaryCity will still provide safe space for illegal aliens.\nhttps://t.co/shsqbzDxzG', truncated=False, entities={'hashtags': [{'text': 'SanctuaryCity', 'indices': [52, 66]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/shsqbzDxzG', 'expanded_url': 'http://jwatch.us/U9iTP8', 'display_url': 'jwatch.us/U9iTP8', 'indices': [117, 140]}]}, metadata={'result_type': 'popular', 'iso_language_code': 'en'}, source='TweetDeck', source_url='https://about.twitter.com/products/tweetdeck', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7fbd07feac50>, _json={'id' ...

# %% [markdown]
# ## 4. Exploring the Dataset

# %% [markdown]
# Twitter gives us a lot of information about each tweet, not just its text. You can read about all the details [here](https://dev.twitter.com/overview/api/tweets). Let's look at one tweet to get a sense of the information we have available. We can access just the first tweet in our list by indexing into it. Note, the first index in the list is actually 0, not 1, so we will actually say `first_ten[0]` to see the first tweet in our list of ten tweets.

# %%
print(first_ten[9]) # Try changing this to any number 0-9, to see other tweets in the list.
# Out:
# Status(_api=<tweepy.api.API object at 0x7fbd07feac50>, _json={'created_at': 'Sat Oct 14 15:15:11 +0000 2017', 'id': 919220043879190528, 'id_str': '919220043879190528', 'text': 'REPLAY: YAF’s Fred Allen Lecture with @benshapiro at UC Berkeley #YAFonCampus #BenAtBerkeley https://t.co/iifaVJU9ZU https://t.co/ZVusv8v9Hy', 'truncated': False, 'entities': {'hashtags': [{'text': 'YAFonCampus', 'indices': [65, 77]}, {'text': 'BenAtBerkeley', 'indices': [78, 92]}], 'symbols': [], 'user_mentions': [{'screen_name': 'benshapiro', 'name': 'Ben Shapiro', 'id': 17995040, 'id_str': '17995040', 'indices': [38, 49]}], 'urls': [{'url': 'https://t.co/iifaVJU9ZU', 'expanded_url': 'http://bit.ly/2wTcmPH', 'display_url': 'bit.ly/2wTcmPH', 'indices': [93, 116]}], 'media': [{'id': 919220040641208320, 'id_str': '919220040641208320', 'indices': [117, 140], 'media_url': 'http://pbs.twimg.com/media/DMG5wbjW4AAdkpa.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMG5wbjW4AAdkpa.jpg', 'url': 'https://t.co/ZVusv8v9Hy', 'display_url': 'pic.twitter.com/ZVusv8v9Hy', 'expanded_url': 'https://twitter.com/yaf/status/919220043879190528/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 480, 'h': 360, 'resize': 'fit'}, 'small': {'w': 480, 'h': 360, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 480, 'h': 360, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 919220040641208320, 'id_str': '919220040641208320', 'indices': [117, 140], 'media_url': 'http://pbs.twimg.com/media/DMG5wbjW4AAdkpa.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMG5wbjW4AAdkpa.jpg', 'url': 'https://t.co/ZVusv8v9Hy', 'display_url': 'pic.twitter.com/ZVusv8v9Hy', 'expanded_url': 'https://twitter.com/yaf/status/919220043879190528/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 480, 'h': 360, 'resize': 'fit'}, 'small': {'w': 480, 'h': 360, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 480, 'h': 360, 'resize': 'fit'}}}]}, 'metadata': {'result_type': 'popular', 'iso_language_code': 'en'}, 'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 16148677, 'id_str': '16148677', 'name': 'YAF', 'screen_name': 'yaf', 'location': 'Reston, VA', 'description': "Young America's Foundation introduces students to conservatism through our campus programs and conferences. The Foundation also preserves the Reagan Ranch.", 'url': 'https://t.co/A3I9nSBnlM', 'entities': {'url': {'urls': [{'url': 'https://t.co/A3I9nSBnlM', 'expanded_url': 'http://www.yaf.org', 'display_url': 'yaf.org', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 39863, 'friends_count': 1570, 'listed_count': 551, 'created_at': 'Fri Sep 05 20:04:51 +0000 2008', 'favourites_count': 4482, 'utc_offset': -14400, 'time_zone': 'Eastern Time (US & Canada)', 'geo_enabled': True, 'verified': True, 'statuses_count': 17673, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '022330', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/123876231/yaf_twitter_bkgd_draft1.jpg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/123876231/yaf_twitter_bkgd_draft1.jpg', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/682327485619519488/kjO5knmV_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/682327485619519488/kjO5knmV_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16148677/1382315291', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'A8C7F7', 'profile_sidebar_fill_color': 'C0DFEC', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, ' ...

# %%
print(first_ten[0].text) # Try this and inspect what it does
# Out:
# JW revealed Berkeley mayor assured Mexican govt his #SanctuaryCity will still provide safe space for illegal aliens.
# https://t.co/shsqbzDxzG

# %%
print(first_ten[0].created_at) # Try this and inspect what it does
# Out:
# 2017-10-15 01:55:00

# %% [markdown]
# ### Question 3:
# Which field contains each of the following attributes:
# 1. The tweet's text?
# 1. The time when the tweet was posted?
# 1. The geographic location of the tweet?
# 1. The source (device and app) where the tweet was written?

# %% [markdown]
# **Answer:**
# 1. text
# 1. created_at
# 1. coordinates
# 1. source

# %% [markdown]
# ## 5. Analyzing the Dataset

# %% [markdown]
# It's time to do analysis! Let's start out by getting a list, where each entry corresponds to how many retweets we got in the first

# %%
retweet_counts = []                      # We start with an empty list called `retweet_counts`.
for tweet in first_ten:                  # Then, we iterate over the tweets in `first_ten`...
    retweet_count = tweet.retweet_count  # And, for each tweet, get the number of retweets...
    retweet_counts.append(retweet_count) # And append that number to our list `retweet_counts`.
    
print(retweet_counts)
# Out:
# [454, 118, 123, 106, 95, 58, 20, 20, 17, 35]

# %% [markdown]
# Let's try and draw it:

# %%
import matplotlib.pyplot as plt
plt.hist(retweet_counts)
plt.xlabel("Retweet counts")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Question 4
# Twitter search api provides three modes (check out this [guide](https://dev.twitter.com/rest/reference/get/search/tweets)) for the result_type: mix, recent, and popular. In the previous code, we retrieved the popular tweets.
# Now it is your turn to retrieve recent 100 tweets and assign them to a new variable (e.g., results_recent100), then plot a histogram for the retweet count of the recent 100 tweets. You can follow our example code if you wish.

# %% [markdown]
# **Answer**

# %%
results_recent100 = tweepy.Cursor(api.search, q='Berkeley', result_type='recent')
first_ten_recent100 = []
for tweet in results_recent100.items(10):
    first_ten_recent100.append(tweet)
retweet_counts_recent100 = []
for tweet in first_ten_recent100:
    retweet_count_recent100 = tweet.retweet_count
    retweet_counts_recent100.append(retweet_count_recent100)

import matplotlib.pyplot as plt
plt.hist(retweet_counts_recent100)
plt.xlabel("Retweet counts")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Question 5
# Compare and contrast between the two histograms for retweet counts of recent and popular 100 tweets that returns from searching the word Berkeley.

# %% [markdown]
# **Answer**:

# %% [markdown]
# Retweet counts of first 10 of recent 100 tweets are very segregated with most have retweet counts less than couple hundreds and some that are equal to 98102. On the other hand, retweet counts of first 10 of popular 100 tweets are very close to each other around hundreds.

# %% [markdown]
# ## Users
# Instead of searching for tweets, you can use Twitter APIs to get details about specific user account. It includes user’s timeline, followers, etc.
#
# Get the latest 10 tweets from an account that interests you (e.g.,  UCBerkeley) twitter account using the following code.

# %%
user_results = api.user_timeline(screen_name='UCBerkeley', count=10)
print(user_results)
user_results_tweets = []           # We start with an empty list called user_results_tweets

for t in user_results:             #Then, we iterate over the tweets in user_results
    user_results_tweets.append(t)#And we'll add each of those tweets to user_results_tweets 
    print(t)
# Out:
# [Status(_api=<tweepy.api.API object at 0x7fbd07feac50>, _json={'created_at': 'Sun Oct 15 22:02:01 +0000 2017', 'id': 919684816559206401, 'id_str': '919684816559206401', 'text': 'ICYMI: 3 Berkeley alums win MacArthur ‘genius’ awards https://t.co/Zx97c1R4bN @macfound #MacFellow #GoBears https://t.co/Kz9WAeSTbr', 'truncated': False, 'entities': {'hashtags': [{'text': 'MacFellow', 'indices': [88, 98]}, {'text': 'GoBears', 'indices': [99, 107]}], 'symbols': [], 'user_mentions': [{'screen_name': 'macfound', 'name': 'MacArthur Foundation', 'id': 14275261, 'id_str': '14275261', 'indices': [78, 87]}], 'urls': [{'url': 'https://t.co/Zx97c1R4bN', 'expanded_url': 'http://bit.ly/2hC3CXO', 'display_url': 'bit.ly/2hC3CXO', 'indices': [54, 77]}], 'media': [{'id': 919684813354819584, 'id_str': '919684813354819584', 'indices': [108, 131], 'media_url': 'http://pbs.twimg.com/media/DMNgdw1V4AAzK9-.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMNgdw1V4AAzK9-.jpg', 'url': 'https://t.co/Kz9WAeSTbr', 'display_url': 'pic.twitter.com/Kz9WAeSTbr', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919684816559206401/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1200, 'h': 624, 'resize': 'fit'}, 'large': {'w': 1200, 'h': 624, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 354, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 919684813354819584, 'id_str': '919684813354819584', 'indices': [108, 131], 'media_url': 'http://pbs.twimg.com/media/DMNgdw1V4AAzK9-.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMNgdw1V4AAzK9-.jpg', 'url': 'https://t.co/Kz9WAeSTbr', 'display_url': 'pic.twitter.com/Kz9WAeSTbr', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919684816559206401/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1200, 'h': 624, 'resize': 'fit'}, 'large': {'w': 1200, 'h': 624, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 354, 'resize': 'fit'}}}]}, 'source': '<a href="http://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 176932593, 'id_str': '176932593', 'name': 'UC Berkeley', 'screen_name': 'UCBerkeley', 'location': 'Berkeley, California', 'description': 'University of California, Berkeley, the premier public institution of higher education', 'url': 'http://t.co/5AQcLU8aoE', 'entities': {'url': {'urls': [{'url': 'http://t.co/5AQcLU8aoE', 'expanded_url': 'http://berkeley.edu', 'display_url': 'berkeley.edu', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 129676, 'friends_count': 1171, 'listed_count': 1621, 'created_at': 'Tue Aug 10 20:40:13 +0000 2010', 'favourites_count': 6491, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'verified': True, 'statuses_count': 13477, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FCFCFC', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/176932593/1398457126', 'profile_link_color': '9D7D0A', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F9EFC8', 'profile_text_color': '152C9D', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'foll ...
# Status(_api=<tweepy.api.API object at 0x7fbd07feac50>, _json={'created_at': 'Sun Oct 15 22:02:01 +0000 2017', 'id': 919684816559206401, 'id_str': '919684816559206401', 'text': 'ICYMI: 3 Berkeley alums win MacArthur ‘genius’ awards https://t.co/Zx97c1R4bN @macfound #MacFellow #GoBears https://t.co/Kz9WAeSTbr', 'truncated': False, 'entities': {'hashtags': [{'text': 'MacFellow', 'indices': [88, 98]}, {'text': 'GoBears', 'indices': [99, 107]}], 'symbols': [], 'user_mentions': [{'screen_name': 'macfound', 'name': 'MacArthur Foundation', 'id': 14275261, 'id_str': '14275261', 'indices': [78, 87]}], 'urls': [{'url': 'https://t.co/Zx97c1R4bN', 'expanded_url': 'http://bit.ly/2hC3CXO', 'display_url': 'bit.ly/2hC3CXO', 'indices': [54, 77]}], 'media': [{'id': 919684813354819584, 'id_str': '919684813354819584', 'indices': [108, 131], 'media_url': 'http://pbs.twimg.com/media/DMNgdw1V4AAzK9-.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMNgdw1V4AAzK9-.jpg', 'url': 'https://t.co/Kz9WAeSTbr', 'display_url': 'pic.twitter.com/Kz9WAeSTbr', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919684816559206401/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1200, 'h': 624, 'resize': 'fit'}, 'large': {'w': 1200, 'h': 624, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 354, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 919684813354819584, 'id_str': '919684813354819584', 'indices': [108, 131], 'media_url': 'http://pbs.twimg.com/media/DMNgdw1V4AAzK9-.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMNgdw1V4AAzK9-.jpg', 'url': 'https://t.co/Kz9WAeSTbr', 'display_url': 'pic.twitter.com/Kz9WAeSTbr', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919684816559206401/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1200, 'h': 624, 'resize': 'fit'}, 'large': {'w': 1200, 'h': 624, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 354, 'resize': 'fit'}}}]}, 'source': '<a href="http://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 176932593, 'id_str': '176932593', 'name': 'UC Berkeley', 'screen_name': 'UCBerkeley', 'location': 'Berkeley, California', 'description': 'University of California, Berkeley, the premier public institution of higher education', 'url': 'http://t.co/5AQcLU8aoE', 'entities': {'url': {'urls': [{'url': 'http://t.co/5AQcLU8aoE', 'expanded_url': 'http://berkeley.edu', 'display_url': 'berkeley.edu', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 129676, 'friends_count': 1171, 'listed_count': 1621, 'created_at': 'Tue Aug 10 20:40:13 +0000 2010', 'favourites_count': 6491, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'verified': True, 'statuses_count': 13477, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FCFCFC', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/176932593/1398457126', 'profile_link_color': '9D7D0A', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F9EFC8', 'profile_text_color': '152C9D', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'follo ...
# Status(_api=<tweepy.api.API object at 0x7fbd07feac50>, _json={'created_at': 'Sun Oct 15 19:04:01 +0000 2017', 'id': 919640021883162624, 'id_str': '919640021883162624', 'text': 'Physics postdoc &amp;amp; mentor awarded prestigious @LOrealUSA fellowship https://t.co/N6KAjwHqoP https://t.co/x4HU0LBeju', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'LOrealUSA', 'name': "L'Oréal USA", 'id': 58602756, 'id_str': '58602756', 'indices': [53, 63]}], 'urls': [{'url': 'https://t.co/N6KAjwHqoP', 'expanded_url': 'http://bit.ly/2hEjlG0', 'display_url': 'bit.ly/2hEjlG0', 'indices': [75, 98]}], 'media': [{'id': 919640019609911296, 'id_str': '919640019609911296', 'indices': [99, 122], 'media_url': 'http://pbs.twimg.com/media/DMM3ubIVAAAs2Y-.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMM3ubIVAAAs2Y-.jpg', 'url': 'https://t.co/x4HU0LBeju', 'display_url': 'pic.twitter.com/x4HU0LBeju', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919640021883162624/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 453, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 750, 'h': 500, 'resize': 'fit'}, 'large': {'w': 750, 'h': 500, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 919640019609911296, 'id_str': '919640019609911296', 'indices': [99, 122], 'media_url': 'http://pbs.twimg.com/media/DMM3ubIVAAAs2Y-.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMM3ubIVAAAs2Y-.jpg', 'url': 'https://t.co/x4HU0LBeju', 'display_url': 'pic.twitter.com/x4HU0LBeju', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919640021883162624/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 453, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 750, 'h': 500, 'resize': 'fit'}, 'large': {'w': 750, 'h': 500, 'resize': 'fit'}}}]}, 'source': '<a href="http://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 176932593, 'id_str': '176932593', 'name': 'UC Berkeley', 'screen_name': 'UCBerkeley', 'location': 'Berkeley, California', 'description': 'University of California, Berkeley, the premier public institution of higher education', 'url': 'http://t.co/5AQcLU8aoE', 'entities': {'url': {'urls': [{'url': 'http://t.co/5AQcLU8aoE', 'expanded_url': 'http://berkeley.edu', 'display_url': 'berkeley.edu', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 129676, 'friends_count': 1171, 'listed_count': 1621, 'created_at': 'Tue Aug 10 20:40:13 +0000 2010', 'favourites_count': 6491, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'verified': True, 'statuses_count': 13477, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FCFCFC', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/176932593/1398457126', 'profile_link_color': '9D7D0A', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F9EFC8', 'profile_text_color': '152C9D', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': No ...
# Status(_api=<tweepy.api.API object at 0x7fbd07feac50>, _json={'created_at': 'Sun Oct 15 18:04:01 +0000 2017', 'id': 919624920740503553, 'id_str': '919624920740503553', 'text': 'BLOG: Summer of #Love language — still compelling after all these years https://t.co/bsjaOd3jjA @GeoffNunberg… https://t.co/Hh83HQtK65', 'truncated': True, 'entities': {'hashtags': [{'text': 'Love', 'indices': [16, 21]}], 'symbols': [], 'user_mentions': [{'screen_name': 'GeoffNunberg', 'name': 'Geoffrey Nunberg', 'id': 39396057, 'id_str': '39396057', 'indices': [96, 109]}], 'urls': [{'url': 'https://t.co/bsjaOd3jjA', 'expanded_url': 'http://bit.ly/2yGegrl', 'display_url': 'bit.ly/2yGegrl', 'indices': [72, 95]}, {'url': 'https://t.co/Hh83HQtK65', 'expanded_url': 'https://twitter.com/i/web/status/919624920740503553', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [111, 134]}]}, 'source': '<a href="http://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 176932593, 'id_str': '176932593', 'name': 'UC Berkeley', 'screen_name': 'UCBerkeley', 'location': 'Berkeley, California', 'description': 'University of California, Berkeley, the premier public institution of higher education', 'url': 'http://t.co/5AQcLU8aoE', 'entities': {'url': {'urls': [{'url': 'http://t.co/5AQcLU8aoE', 'expanded_url': 'http://berkeley.edu', 'display_url': 'berkeley.edu', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 129676, 'friends_count': 1171, 'listed_count': 1621, 'created_at': 'Tue Aug 10 20:40:13 +0000 2010', 'favourites_count': 6491, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'verified': True, 'statuses_count': 13477, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FCFCFC', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/176932593/1398457126', 'profile_link_color': '9D7D0A', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F9EFC8', 'profile_text_color': '152C9D', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 4, 'favorite_count': 6, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2017, 10, 15, 18, 4, 1), id=919624920740503553, id_str='919624920740503553', text='BLOG: Summer of #Love language — still compelling after all these years https://t.co/bsjaOd3jjA @GeoffNunberg… https://t.co/Hh83HQtK65', truncated=True, entities={'hashtags': [{'text': 'Love', 'indices': [16, 21]}], 'symbols': [], 'user_mentions': [{'screen_name': 'GeoffNunberg', 'name': 'Geoffrey Nunberg', 'id': 39396057, 'id_str': '39396057', 'indices': [96, 109]}], 'urls': [{'url': 'https://t.co/bsjaOd3jjA', 'expanded_url': 'http://bit.ly/2yGegrl', 'display_url': 'bit.ly/2yGegrl', 'indices': [72, 95]}, {'url': 'https://t.co/Hh83HQtK65', 'expanded_url': 'https://twitter.com/i/web/status/919624920740503553', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [111, 134]}]} ...
# Status(_api=<tweepy.api.API object at 0x7fbd07feac50>, _json={'created_at': 'Sun Oct 15 17:03:04 +0000 2017', 'id': 919609583957549056, 'id_str': '919609583957549056', 'text': "Sailing an ocean of challenges to stage 'Metamorphoses' https://t.co/VlDny8vd0S #theater #water https://t.co/QMNGky54lu", 'truncated': False, 'entities': {'hashtags': [{'text': 'theater', 'indices': [80, 88]}, {'text': 'water', 'indices': [89, 95]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/VlDny8vd0S', 'expanded_url': 'http://bit.ly/2yKR5MV', 'display_url': 'bit.ly/2yKR5MV', 'indices': [56, 79]}], 'media': [{'id': 919609573329080320, 'id_str': '919609573329080320', 'indices': [96, 119], 'media_url': 'http://pbs.twimg.com/media/DMMcCN5UEAAhRkv.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMMcCN5UEAAhRkv.jpg', 'url': 'https://t.co/QMNGky54lu', 'display_url': 'pic.twitter.com/QMNGky54lu', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919609583957549056/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 750, 'h': 500, 'resize': 'fit'}, 'large': {'w': 750, 'h': 500, 'resize': 'fit'}, 'small': {'w': 680, 'h': 453, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]}, 'extended_entities': {'media': [{'id': 919609573329080320, 'id_str': '919609573329080320', 'indices': [96, 119], 'media_url': 'http://pbs.twimg.com/media/DMMcCN5UEAAhRkv.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMMcCN5UEAAhRkv.jpg', 'url': 'https://t.co/QMNGky54lu', 'display_url': 'pic.twitter.com/QMNGky54lu', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919609583957549056/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 750, 'h': 500, 'resize': 'fit'}, 'large': {'w': 750, 'h': 500, 'resize': 'fit'}, 'small': {'w': 680, 'h': 453, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}, {'id': 919609575929556992, 'id_str': '919609575929556992', 'indices': [96, 119], 'media_url': 'http://pbs.twimg.com/media/DMMcCXlUMAAnIuo.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMMcCXlUMAAnIuo.jpg', 'url': 'https://t.co/QMNGky54lu', 'display_url': 'pic.twitter.com/QMNGky54lu', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919609583957549056/photo/1', 'type': 'photo', 'sizes': {'large': {'w': 750, 'h': 500, 'resize': 'fit'}, 'medium': {'w': 750, 'h': 500, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 453, 'resize': 'fit'}}}, {'id': 919609579037536256, 'id_str': '919609579037536256', 'indices': [96, 119], 'media_url': 'http://pbs.twimg.com/media/DMMcCjKUMAA4_f5.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMMcCjKUMAA4_f5.jpg', 'url': 'https://t.co/QMNGky54lu', 'display_url': 'pic.twitter.com/QMNGky54lu', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919609583957549056/photo/1', 'type': 'photo', 'sizes': {'large': {'w': 750, 'h': 500, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 453, 'resize': 'fit'}, 'medium': {'w': 750, 'h': 500, 'resize': 'fit'}}}, {'id': 919609581302513664, 'id_str': '919609581302513664', 'indices': [96, 119], 'media_url': 'http://pbs.twimg.com/media/DMMcCrmVAAAc3su.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMMcCrmVAAAc3su.jpg', 'url': 'https://t.co/QMNGky54lu', 'display_url': 'pic.twitter.com/QMNGky54lu', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919609583957549056/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 454, 'resize': 'fit'}, 'medium': {'w': 750, 'h': 501, 'resize': 'fit'}, 'large': {'w': 750, 'h': 501, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]}, 'source': '<a href="http://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 176932593, 'id_str': '176932593', 'name': 'UC Berkeley', 'screen_name': 'UCBerkeley', 'locati ...
# Status(_api=<tweepy.api.API object at 0x7fbd07feac50>, _json={'created_at': 'Sun Oct 15 16:58:53 +0000 2017', 'id': 919608530302156805, 'id_str': '919608530302156805', 'text': 'RT @dan_kammen: Food delivery drones on campus  (already very, very @starwars) now distributing free particulate masks @CAL_FIRE https://t.…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'dan_kammen', 'name': 'Daniel M Kammen', 'id': 3184574881, 'id_str': '3184574881', 'indices': [3, 14]}, {'screen_name': 'starwars', 'name': 'Star Wars', 'id': 20106852, 'id_str': '20106852', 'indices': [68, 77]}, {'screen_name': 'CAL_FIRE', 'name': 'CAL FIRE', 'id': 21249970, 'id_str': '21249970', 'indices': [119, 128]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 176932593, 'id_str': '176932593', 'name': 'UC Berkeley', 'screen_name': 'UCBerkeley', 'location': 'Berkeley, California', 'description': 'University of California, Berkeley, the premier public institution of higher education', 'url': 'http://t.co/5AQcLU8aoE', 'entities': {'url': {'urls': [{'url': 'http://t.co/5AQcLU8aoE', 'expanded_url': 'http://berkeley.edu', 'display_url': 'berkeley.edu', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 129676, 'friends_count': 1171, 'listed_count': 1621, 'created_at': 'Tue Aug 10 20:40:13 +0000 2010', 'favourites_count': 6491, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'verified': True, 'statuses_count': 13477, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FCFCFC', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/176932593/1398457126', 'profile_link_color': '9D7D0A', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F9EFC8', 'profile_text_color': '152C9D', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Oct 15 16:49:25 +0000 2017', 'id': 919606148424241152, 'id_str': '919606148424241152', 'text': 'Food delivery drones on campus  (already very, very @starwars) now distributing free particulate masks @CAL_FIRE https://t.co/B7C1w0q85g', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'starwars', 'name': 'Star Wars', 'id': 20106852, 'id_str': '20106852', 'indices': [52, 61]}, {'screen_name': 'CAL_FIRE', 'name': 'CAL FIRE', 'id': 21249970, 'id_str': '21249970', 'indices': [103, 112]}], 'urls': [], 'media': [{'id': 919606113179283457, 'id_str': '919606113179283457', 'indices': [113, 136], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/919606113179283457/pu/img/l-I7reWqTmMnYox9.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/919606113179283457/pu/img/l-I7reWqTmMnYox9.jpg', 'url': 'https://t.co/B7C1w0q85g', 'display_url': 'pic.twitter.com/B7C1w0q85g', 'expanded_url': 'https://twitter.com/dan_kammen/status/919606148424241152/vide ...
# Status(_api=<tweepy.api.API object at 0x7fbd07feac50>, _json={'created_at': 'Sun Oct 15 16:05:02 +0000 2017', 'id': 919594975246946304, 'id_str': '919594975246946304', 'text': "Shanka Sastry (MS '79, MS '80, PhD '81) will step down as engineering dean https://t.co/XMj34icLav https://t.co/JP4DCIyvfK", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/XMj34icLav', 'expanded_url': 'http://bit.ly/2hFyyqc', 'display_url': 'bit.ly/2hFyyqc', 'indices': [75, 98]}], 'media': [{'id': 919594973158244357, 'id_str': '919594973158244357', 'indices': [99, 122], 'media_url': 'http://pbs.twimg.com/media/DMMOwYBVAAU0gPQ.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMMOwYBVAAU0gPQ.jpg', 'url': 'https://t.co/JP4DCIyvfK', 'display_url': 'pic.twitter.com/JP4DCIyvfK', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919594975246946304/photo/1', 'type': 'photo', 'sizes': {'large': {'w': 1200, 'h': 649, 'resize': 'fit'}, 'small': {'w': 680, 'h': 368, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 649, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]}, 'extended_entities': {'media': [{'id': 919594973158244357, 'id_str': '919594973158244357', 'indices': [99, 122], 'media_url': 'http://pbs.twimg.com/media/DMMOwYBVAAU0gPQ.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMMOwYBVAAU0gPQ.jpg', 'url': 'https://t.co/JP4DCIyvfK', 'display_url': 'pic.twitter.com/JP4DCIyvfK', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919594975246946304/photo/1', 'type': 'photo', 'sizes': {'large': {'w': 1200, 'h': 649, 'resize': 'fit'}, 'small': {'w': 680, 'h': 368, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 649, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]}, 'source': '<a href="http://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 176932593, 'id_str': '176932593', 'name': 'UC Berkeley', 'screen_name': 'UCBerkeley', 'location': 'Berkeley, California', 'description': 'University of California, Berkeley, the premier public institution of higher education', 'url': 'http://t.co/5AQcLU8aoE', 'entities': {'url': {'urls': [{'url': 'http://t.co/5AQcLU8aoE', 'expanded_url': 'http://berkeley.edu', 'display_url': 'berkeley.edu', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 129676, 'friends_count': 1171, 'listed_count': 1621, 'created_at': 'Tue Aug 10 20:40:13 +0000 2010', 'favourites_count': 6491, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'verified': True, 'statuses_count': 13477, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FCFCFC', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/176932593/1398457126', 'profile_link_color': '9D7D0A', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F9EFC8', 'profile_text_color': '152C9D', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0 ...
# Status(_api=<tweepy.api.API object at 0x7fbd07feac50>, _json={'created_at': 'Sun Oct 15 07:30:01 +0000 2017', 'id': 919465370628505600, 'id_str': '919465370628505600', 'text': '#CRISPR-Gold fixes Duchenne muscular dystrophy mutation in mice https://t.co/hGrIoGX970 #InThisGen https://t.co/7V1fmkroTs', 'truncated': False, 'entities': {'hashtags': [{'text': 'CRISPR', 'indices': [0, 7]}, {'text': 'InThisGen', 'indices': [88, 98]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/hGrIoGX970', 'expanded_url': 'http://bit.ly/2xWCzA0', 'display_url': 'bit.ly/2xWCzA0', 'indices': [64, 87]}], 'media': [{'id': 919465368426442752, 'id_str': '919465368426442752', 'indices': [99, 122], 'media_url': 'http://pbs.twimg.com/media/DMKY4YxU8AAc-nI.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMKY4YxU8AAc-nI.jpg', 'url': 'https://t.co/7V1fmkroTs', 'display_url': 'pic.twitter.com/7V1fmkroTs', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919465370628505600/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 453, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 750, 'h': 500, 'resize': 'fit'}, 'large': {'w': 750, 'h': 500, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 919465368426442752, 'id_str': '919465368426442752', 'indices': [99, 122], 'media_url': 'http://pbs.twimg.com/media/DMKY4YxU8AAc-nI.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMKY4YxU8AAc-nI.jpg', 'url': 'https://t.co/7V1fmkroTs', 'display_url': 'pic.twitter.com/7V1fmkroTs', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919465370628505600/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 453, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 750, 'h': 500, 'resize': 'fit'}, 'large': {'w': 750, 'h': 500, 'resize': 'fit'}}}]}, 'source': '<a href="http://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 176932593, 'id_str': '176932593', 'name': 'UC Berkeley', 'screen_name': 'UCBerkeley', 'location': 'Berkeley, California', 'description': 'University of California, Berkeley, the premier public institution of higher education', 'url': 'http://t.co/5AQcLU8aoE', 'entities': {'url': {'urls': [{'url': 'http://t.co/5AQcLU8aoE', 'expanded_url': 'http://berkeley.edu', 'display_url': 'berkeley.edu', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 129676, 'friends_count': 1171, 'listed_count': 1621, 'created_at': 'Tue Aug 10 20:40:13 +0000 2010', 'favourites_count': 6491, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'verified': True, 'statuses_count': 13477, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FCFCFC', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/176932593/1398457126', 'profile_link_color': '9D7D0A', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F9EFC8', 'profile_text_color': '152C9D', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'pla ...
# Status(_api=<tweepy.api.API object at 0x7fbd07feac50>, _json={'created_at': 'Sun Oct 15 03:51:03 +0000 2017', 'id': 919410265086607360, 'id_str': '919410265086607360', 'text': 'Berkeley students, alums take on ‘back-breaking’ work at wildfire evacuation center https://t.co/3CeDhWO0fo @calveterans #wildfires', 'truncated': False, 'entities': {'hashtags': [{'text': 'wildfires', 'indices': [121, 131]}], 'symbols': [], 'user_mentions': [{'screen_name': 'calveterans', 'name': 'Cal Veterans Group', 'id': 155242352, 'id_str': '155242352', 'indices': [108, 120]}], 'urls': [{'url': 'https://t.co/3CeDhWO0fo', 'expanded_url': 'http://bit.ly/2yMgUMx', 'display_url': 'bit.ly/2yMgUMx', 'indices': [84, 107]}]}, 'source': '<a href="http://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 176932593, 'id_str': '176932593', 'name': 'UC Berkeley', 'screen_name': 'UCBerkeley', 'location': 'Berkeley, California', 'description': 'University of California, Berkeley, the premier public institution of higher education', 'url': 'http://t.co/5AQcLU8aoE', 'entities': {'url': {'urls': [{'url': 'http://t.co/5AQcLU8aoE', 'expanded_url': 'http://berkeley.edu', 'display_url': 'berkeley.edu', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 129676, 'friends_count': 1171, 'listed_count': 1621, 'created_at': 'Tue Aug 10 20:40:13 +0000 2010', 'favourites_count': 6491, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'verified': True, 'statuses_count': 13477, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FCFCFC', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/176932593/1398457126', 'profile_link_color': '9D7D0A', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F9EFC8', 'profile_text_color': '152C9D', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 10, 'favorite_count': 49, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2017, 10, 15, 3, 51, 3), id=919410265086607360, id_str='919410265086607360', text='Berkeley students, alums take on ‘back-breaking’ work at wildfire evacuation center https://t.co/3CeDhWO0fo @calveterans #wildfires', truncated=False, entities={'hashtags': [{'text': 'wildfires', 'indices': [121, 131]}], 'symbols': [], 'user_mentions': [{'screen_name': 'calveterans', 'name': 'Cal Veterans Group', 'id': 155242352, 'id_str': '155242352', 'indices': [108, 120]}], 'urls': [{'url': 'https://t.co/3CeDhWO0fo', 'expanded_url': 'http://bit.ly/2yMgUMx', 'display_url': 'bit.ly/2yMgUMx', 'indices': [84, 107]}]}, source='Sprout Social', source_url='http://sproutsocial.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7fbd07feac50>, _json={'id': 176932593, 'id_str': '176932593', 'name': 'UC B ...
# Status(_api=<tweepy.api.API object at 0x7fbd07feac50>, _json={'created_at': 'Sat Oct 14 18:04:02 +0000 2017', 'id': 919262538235125762, 'id_str': '919262538235125762', 'text': 'A reporter reflects: ‘We are living in the eternal Now’ https://t.co/HdJ9AigNEL @californiamag #wildfires https://t.co/dspHqPxKZu', 'truncated': False, 'entities': {'hashtags': [{'text': 'wildfires', 'indices': [95, 105]}], 'symbols': [], 'user_mentions': [{'screen_name': 'californiamag', 'name': 'CALIFORNIA Magazine', 'id': 54687857, 'id_str': '54687857', 'indices': [80, 94]}], 'urls': [{'url': 'https://t.co/HdJ9AigNEL', 'expanded_url': 'http://bit.ly/2yJU201', 'display_url': 'bit.ly/2yJU201', 'indices': [56, 79]}], 'media': [{'id': 919262536108613633, 'id_str': '919262536108613633', 'indices': [106, 129], 'media_url': 'http://pbs.twimg.com/media/DMHgZ_gUIAEiGj8.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMHgZ_gUIAEiGj8.jpg', 'url': 'https://t.co/dspHqPxKZu', 'display_url': 'pic.twitter.com/dspHqPxKZu', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919262538235125762/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 453, 'resize': 'fit'}, 'medium': {'w': 750, 'h': 500, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 750, 'h': 500, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 919262536108613633, 'id_str': '919262536108613633', 'indices': [106, 129], 'media_url': 'http://pbs.twimg.com/media/DMHgZ_gUIAEiGj8.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMHgZ_gUIAEiGj8.jpg', 'url': 'https://t.co/dspHqPxKZu', 'display_url': 'pic.twitter.com/dspHqPxKZu', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919262538235125762/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 453, 'resize': 'fit'}, 'medium': {'w': 750, 'h': 500, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 750, 'h': 500, 'resize': 'fit'}}}]}, 'source': '<a href="http://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 176932593, 'id_str': '176932593', 'name': 'UC Berkeley', 'screen_name': 'UCBerkeley', 'location': 'Berkeley, California', 'description': 'University of California, Berkeley, the premier public institution of higher education', 'url': 'http://t.co/5AQcLU8aoE', 'entities': {'url': {'urls': [{'url': 'http://t.co/5AQcLU8aoE', 'expanded_url': 'http://berkeley.edu', 'display_url': 'berkeley.edu', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 129676, 'friends_count': 1171, 'listed_count': 1621, 'created_at': 'Tue Aug 10 20:40:13 +0000 2010', 'favourites_count': 6491, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'verified': True, 'statuses_count': 13477, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FCFCFC', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/176932593/1398457126', 'profile_link_color': '9D7D0A', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F9EFC8', 'profile_text_color': '152C9D', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False,  ...
# Status(_api=<tweepy.api.API object at 0x7fbd07feac50>, _json={'created_at': 'Sat Oct 14 17:03:01 +0000 2017', 'id': 919247182657503232, 'id_str': '919247182657503232', 'text': 'Students’ journey from incarceration to classrooms featured in premiered film https://t.co/Dd5bC7IYZw @FITEfilm… https://t.co/qwn6ICGonW', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'FITEfilm', 'name': 'FITE Film', 'id': 4739106354, 'id_str': '4739106354', 'indices': [102, 111]}], 'urls': [{'url': 'https://t.co/Dd5bC7IYZw', 'expanded_url': 'http://bit.ly/2hHxIta', 'display_url': 'bit.ly/2hHxIta', 'indices': [78, 101]}, {'url': 'https://t.co/qwn6ICGonW', 'expanded_url': 'https://twitter.com/i/web/status/919247182657503232', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [113, 136]}]}, 'source': '<a href="http://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 176932593, 'id_str': '176932593', 'name': 'UC Berkeley', 'screen_name': 'UCBerkeley', 'location': 'Berkeley, California', 'description': 'University of California, Berkeley, the premier public institution of higher education', 'url': 'http://t.co/5AQcLU8aoE', 'entities': {'url': {'urls': [{'url': 'http://t.co/5AQcLU8aoE', 'expanded_url': 'http://berkeley.edu', 'display_url': 'berkeley.edu', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 129676, 'friends_count': 1171, 'listed_count': 1621, 'created_at': 'Tue Aug 10 20:40:13 +0000 2010', 'favourites_count': 6491, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'verified': True, 'statuses_count': 13477, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FCFCFC', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/176932593/1398457126', 'profile_link_color': '9D7D0A', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F9EFC8', 'profile_text_color': '152C9D', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 5, 'favorite_count': 11, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2017, 10, 14, 17, 3, 1), id=919247182657503232, id_str='919247182657503232', text='Students’ journey from incarceration to classrooms featured in premiered film https://t.co/Dd5bC7IYZw @FITEfilm… https://t.co/qwn6ICGonW', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'FITEfilm', 'name': 'FITE Film', 'id': 4739106354, 'id_str': '4739106354', 'indices': [102, 111]}], 'urls': [{'url': 'https://t.co/Dd5bC7IYZw', 'expanded_url': 'http://bit.ly/2hHxIta', 'display_url': 'bit.ly/2hHxIta', 'indices': [78, 101]}, {'url': 'https://t.co/qwn6ICGonW', 'expanded_url': 'https://twitter.com/i/web/status/919247182657503232', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [113, 136]}]}, source='Sprout Social', source_url='http://sproutsocial.com', in_reply_to_sta ...

# %%
#Let's look at one tweet
print(user_results_tweets[0])
print("Aspen")
# Out:
# Status(_api=<tweepy.api.API object at 0x7fbd07feac50>, _json={'created_at': 'Sun Oct 15 22:02:01 +0000 2017', 'id': 919684816559206401, 'id_str': '919684816559206401', 'text': 'ICYMI: 3 Berkeley alums win MacArthur ‘genius’ awards https://t.co/Zx97c1R4bN @macfound #MacFellow #GoBears https://t.co/Kz9WAeSTbr', 'truncated': False, 'entities': {'hashtags': [{'text': 'MacFellow', 'indices': [88, 98]}, {'text': 'GoBears', 'indices': [99, 107]}], 'symbols': [], 'user_mentions': [{'screen_name': 'macfound', 'name': 'MacArthur Foundation', 'id': 14275261, 'id_str': '14275261', 'indices': [78, 87]}], 'urls': [{'url': 'https://t.co/Zx97c1R4bN', 'expanded_url': 'http://bit.ly/2hC3CXO', 'display_url': 'bit.ly/2hC3CXO', 'indices': [54, 77]}], 'media': [{'id': 919684813354819584, 'id_str': '919684813354819584', 'indices': [108, 131], 'media_url': 'http://pbs.twimg.com/media/DMNgdw1V4AAzK9-.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMNgdw1V4AAzK9-.jpg', 'url': 'https://t.co/Kz9WAeSTbr', 'display_url': 'pic.twitter.com/Kz9WAeSTbr', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919684816559206401/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1200, 'h': 624, 'resize': 'fit'}, 'large': {'w': 1200, 'h': 624, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 354, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 919684813354819584, 'id_str': '919684813354819584', 'indices': [108, 131], 'media_url': 'http://pbs.twimg.com/media/DMNgdw1V4AAzK9-.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DMNgdw1V4AAzK9-.jpg', 'url': 'https://t.co/Kz9WAeSTbr', 'display_url': 'pic.twitter.com/Kz9WAeSTbr', 'expanded_url': 'https://twitter.com/UCBerkeley/status/919684816559206401/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1200, 'h': 624, 'resize': 'fit'}, 'large': {'w': 1200, 'h': 624, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 354, 'resize': 'fit'}}}]}, 'source': '<a href="http://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 176932593, 'id_str': '176932593', 'name': 'UC Berkeley', 'screen_name': 'UCBerkeley', 'location': 'Berkeley, California', 'description': 'University of California, Berkeley, the premier public institution of higher education', 'url': 'http://t.co/5AQcLU8aoE', 'entities': {'url': {'urls': [{'url': 'http://t.co/5AQcLU8aoE', 'expanded_url': 'http://berkeley.edu', 'display_url': 'berkeley.edu', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 129676, 'friends_count': 1171, 'listed_count': 1621, 'created_at': 'Tue Aug 10 20:40:13 +0000 2010', 'favourites_count': 6491, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'verified': True, 'statuses_count': 13477, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FCFCFC', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/790178413/d030b080c387ea27a2b9c17fbce00192.jpeg', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/667569099300405248/ba6dE8pg_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/176932593/1398457126', 'profile_link_color': '9D7D0A', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F9EFC8', 'profile_text_color': '152C9D', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'follo ...
# Aspen

# %%
#print the text of the first 10 tweets
for tweet in user_results_tweets:
    print(tweet.created_at.strftime("%Y-%b-%d %H:%M"))
    print(tweet.text)
    print()
# Out:
# 2017-Oct-15 22:02
# ICYMI: 3 Berkeley alums win MacArthur ‘genius’ awards https://t.co/Zx97c1R4bN @macfound #MacFellow #GoBears https://t.co/Kz9WAeSTbr
#
# 2017-Oct-15 19:04
# Physics postdoc &amp;amp; mentor awarded prestigious @LOrealUSA fellowship https://t.co/N6KAjwHqoP https://t.co/x4HU0LBeju
#
# 2017-Oct-15 18:04
# BLOG: Summer of #Love language — still compelling after all these years https://t.co/bsjaOd3jjA @GeoffNunberg… https://t.co/Hh83HQtK65
#
# 2017-Oct-15 17:03
# Sailing an ocean of challenges to stage 'Metamorphoses' https://t.co/VlDny8vd0S #theater #water https://t.co/QMNGky54lu
#
# 2017-Oct-15 16:58
# RT @dan_kammen: Food delivery drones on campus  (already very, very @starwars) now distributing free particulate masks @CAL_FIRE https://t.…
#
# 2017-Oct-15 16:05
# Shanka Sastry (MS '79, MS '80, PhD '81) will step down as engineering dean https://t.co/XMj34icLav https://t.co/JP4DCIyvfK
#
# 2017-Oct-15 07:30
# #CRISPR-Gold fixes Duchenne muscular dystrophy mutation in mice https://t.co/hGrIoGX970 #InThisGen https://t.co/7V1fmkroTs
#
# 2017-Oct-15 03:51
# Berkeley students, alums take on ‘back-breaking’ work at wildfire evacuation center https://t.co/3CeDhWO0fo @calveterans #wildfires
#
# 2017-Oct-14 18:04
# A reporter reflects: ‘We are living in the eternal Now’ https://t.co/HdJ9AigNEL @californiamag #wildfires https://t.co/dspHqPxKZu
#
# 2017-Oct-14 17:03
# Students’ journey from incarceration to classrooms featured in premiered film https://t.co/Dd5bC7IYZw @FITEfilm… https://t.co/qwn6ICGonW

# %% [markdown]
# ### Question 6
#
# Look at the text of retrieved tweets and compare them to the latest 10 tweets of the [web interface](https://twitter.com/UCBerkeley) for the same user. Do you see any difference?

# %% [markdown]
# **Answer**:
#
# 1. The pinned tweet is not among the first ten tweets.
# 2. URIs linked to outside websites are different.
# 3. No pictures are in the texts but given URIs to link to the tweets, which include pictures.

# %% [markdown]
# Get a list of a followers for UCBerkeley.

# %%
followers_list = []
followers_results = api.followers(screen_name='UCBerkeley', count=200)
for f in followers_results:
    followers_list.append(f)
for f in followers_list:
    print(f.name)
# Out:
# Nicholas Larus-Stone
# Robbie Edwards
# The Real Safahri
# Amareah Watkins
# Nora Spence
# Zinda yem
# Emil Faena
# D'Maris Coffman
# Jorge Senchi
# Donald Frank Travins
# Cavanshir Manafov
# Andy Si
# Uriel Rodriguez
# Natalia Capovilla
# Hadild18
# RedSnow Robotics
# Kkkk
# PloufSF
# Bonny
# Marty
# Joseph Steinberg
# Gabriel Rodrigues
# Glenna
# Rock Tree
# Ivan Uhlianytsia
# Meagan.
# shaun
# Laura Martin
# Florencia
# 💕ᴄʜʀɪꜱᴛɪɴᴀ💕
# Caleb Dyess
# San Diego State
# Yocelyn 💎❄❄
# Roseville High
# Niel Caldwell
# Fernando Perla
# Am
# Ghandi Makhzoum
# おすし かっちん
# amber
# Nik Jin
# Daniel Resendiz
# luwarrior
# Perman Jorayev
# Er Mihir Ranjan Sahu
# DisRE GANG
# Manan Patel
# 頹廢文人Blues
# Alexis Augusto
# William Fong
# Kathy Wade
# Exam Testing
# J. M. Brenna
# XiaoyiHao
# Hugh YT Lee
# Tournesol
# Taylor Fallin
# Hakeem J. Jefferson
# 任鹏举
# Sherlock
# Amir Zamir
# Perceptor The Sight
# みんみん(EMIKO)
# Vicky Shi
# ash
# Min-ju Kim
# Kevin Teas
# Nsjs
# nachi mori
# Moon One Base
# ㅤ🄸🄰🄽𓅪
# Mminci
# 爆上げの人生で
# Emmanuela Greenblatt
# Erich Reimer
# Marco
# Preetam sarma
# Lucho González
# UCR GSOE
# Elsa Ortiz
# Jose
# g
# SW4T
# Don Thomas Mallillin
# John R. Kjamanka
# Brenda Lopez
# Anastasya Al-Jabar
# Victoria Rios
# Michael Rosa
# Carl hopson
# garrett
# Jeff Murphy
# frederick p. bauer
# Ricardo Scheller
# Mithun Das
# Wayne Rechnitz
# Baptiste J Décatrel
# Mary milenic
# Bryan Vuong
# LegendMaker96 [TeEm]
# Jerika Lorraine
# Alfonso loya
# Meysam Keshavarz
# Marco Robinson
# reggie smith
# Stephanie Lamarre
# jwh1958@icloud.com
# Erin Spear
# S🔥♐ Force of Nature
# Amina Minaj
# Eric Larson
# CJ Graham Mathews
# Carlos Mendoza
# Sherrie flagg
# Perry vw
# Min Lee
# Makana Roh
# BESO & Partner
# Les délices d'Anne
# Matt Campos
# Iam_mush
# #Tshipik1jnaked PaGE
# Jamshid Khan Afridi
# Manuel Cesarini
# Jihyun Kim
# Atarah Jeffers
# Mayra mendez
# Sally Mathews
# ajswanny
# Carlo lips
# Ghosty
# bean
# Esreal Bell
# oucheikh abdelkarim
# Jeffrey schwartz
# Jacob George
# 🌸mikeyla🌸
# jen 🐳
# Grace
# A-Follower
# J. Ariyah
# Berkay Özerbay
# Jennie Weise
# Nishan Amgain
# FireSim
# ercsland
# Dirk diggler
# A&R Marque Midas
# Tye Wilson
# LUIZA DELFINA RAMOS
# Claudine
# André Souza
# Yung Rénzél 🏇
# Roy Louis
# ᴍɪᴋᴇ  ひ
# Soi Nish
# GERARDO REYES
# haiguo
# Muggsy 🇨🇦
# Nyaradzo
# Kendal Asprec
# Prince Mathew
# nothingtoseehere
# Sérgio Costa
# Ragunath Swaminathan
# Dani Schumacher
# kimphobia
# Fate2Fix
# Pranjal Jain
# Rohan Balan
# Jack
# Greg Holden
# I. b Inyang
# Phuong Tran
# Joslyn Maenner
# Y
# Huilin
# dennis
# Dave MacKinnon
# Socatoa
# Anthony J. Miller
# Stock Options Picks
# James W. Neidhardt
# Priscilla Kalugdan
# Suchit Arora
# ミトラ 政経
# jordan coyle
# Natalia Klimova
# Gabriel trinidad
# Dilbagh singh
# Aditya Agarwal 6498
# Fani Basyari
# Brian m
# Matthew Wen
# Jennie Brand
# Eva
# Patrick Carroll
# Logan Daniel
# Abigail Cartier
# Khalid Furkhunda

# %% [markdown]
# There’s a limit on how many users can be returned by one request. If you need more, please read [using cursors to navigate collections](https://dev.twitter.com/overview/api/cursoring).

# %% [markdown]
# ### Extra Credit Question
# We saw how to use Twitter API to search for tweets. The [Search API](https://dev.twitter.com/rest/public/search) has an option to filter the query results by geo location. The parameter value is specified by ”latitude,longitude,radius” (check out the documentation of API  for more information). Compare the top 10 popular tweets text that contain the word 'berkeley' from four geo locations: Berkeley, Kansas City, New York, and Barcelona Spain.

# %% [markdown]
# **Answer:**

# %%
pop_tweets_BC = tweepy.Cursor(api.search, q='Berkeley', result_type='popular', geo_code="37.871593,-122.272747")
pop_tweets_KC = tweepy.Cursor(api.search, q='Berkeley', result_type='popular', geo_code="39.099727, -94.578567")
pop_tweets_NY = tweepy.Cursor(api.search, q='Berkeley', result_type='popular', geo_code="40.712784, -74.005941")
pop_tweets_BS = tweepy.Cursor(api.search, q='Berkeley', result_type='popular', geo_code="41.385064, -2.173403")

top10BC = []
top10KC = []
top10NY = []
top10BS = []

for tweet in pop_tweets_BC.items(10):
    top10BC.append(tweet)
for tweet in pop_tweets_KC.items(10):
    top10KC.append(tweet)
for tweet in pop_tweets_NY.items(10):
    top10NY.append(tweet)
for tweet in pop_tweets_BS.items(10):
    top10BS.append(tweet)

print(len(top10BC))
print(len(top10KC))
print(len(top10NY))
print(len(top10BS))
# Out:
# 10
# 10
# 10
# 10

# %% [markdown]
# ### Extra Credit Question
# Based on profile_location in the follower data, Compare between the followers of Donald Trump and Hillary Clinton in terms of their locations. We are curious as to whether or not there is a difference locationally between Clinton followers and Trump followers (*note following does not necessarily mean supporting :-)*)
#
# We can do this by seeing where their respective lists have commonality.  Make a list of similar places!
#
# Advanced (optional): Make your implementation faster for finding the similar places! Think about changing data structure.

# %% [markdown]
# **Answer:**

# %%
users_trump_followers = api.followers(screen_name="realDonaldTrump", count=100)
names_followers_trump = []
for follower in users_trump_followers:
    if follower.location:
        names_followers_trump.append(follower.location)
        
print("Trump's followers: ")
for f in names_followers_trump:
    print(f)
    
users_clinton_followers = api.followers(screen_name="HillaryClinton", count=100)
names_followers_clinton = []
for follower in users_clinton_followers:
    if follower.location:
        names_followers_clinton.append(follower.location)
        
print("Hillary's followers: ")
for f in names_followers_clinton:
    print(f)
    
similar_cities = []
for follower_c in names_followers_clinton:
    for follower_t in names_followers_trump:
       if follower_c == follower_t:
        similar_cities.append(follower_c)
print(similar_cities)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-101-4f65cacc9057> in <module>()
# ----> 1 users_trump_followers = api.followers(screen_name="realDonaldTrump", count=10)
#       2 # names_followers_trump = []
#       3 # for follower in users_trump_followers:
#       4 #     if follower.location:
#       5 #         names_followers_trump.append(follower.location)
#
# /srv/app/venv/lib/python3.6/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     243             return method
#     244         else:
# --> 245             return method.execute()
#     246
#     247     # Set pagination mode
#
# /srv/app/venv/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     225
#     226                 if is_rate_limit_error_message(error_msg):
# --> 227                     raise RateLimitError(error_msg, resp)
#     228                 else:
#     229                     raise TweepError(error_msg, resp, api_code=api_error_code)
#
# RateLimitError: [{'message': 'Rate limit exceeded', 'code': 88}]

# %% [markdown]
# ### Submitting the assignment
#
# - Delete your Twitter API credentials, ie. re-assign `consumer_key`, `consumer_secret`, `access_key`, and `access_secret` to empty strings so that we won't see your credentials when you save and sumbit it.
# - Save this jupyter notebook as a pdf. Click File, Download as, PDF via LaTex (.pdf).
# - Upload the pdf file into bcourses under Assignment 2.
